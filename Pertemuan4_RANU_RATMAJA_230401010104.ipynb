# %% [markdown]
# <a href="https://colab.research.google.com/github/RanzCoder119/MK_DataScience_2026/blob/main/Pertemuan4_RANU_RATMAJA_230401010104.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice 4 - Klasifikasi KNN
#
# **Nama:** RANU RATMAJA
# **NIM:** 230401010104
# **Mata Kuliah: Data Science | Prodi Informatika**

# %% [markdown]
# ## Import Library & Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Statistik Deskriptif

# %%
df = pd.DataFrame(bc.data, columns=bc.feature_names)
df["target"] = bc.target
display(df.iloc[:,:5].describe())
# Out:
# <table class="dataframe table table-striped">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mean radius</th>
#       <th>mean texture</th>
#       <th>mean perimeter</th>
#       <th>mean area</th>
#       <th>mean smoothness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>569.000</td>
#       <td>569.000</td>
#       <td>569.000</td>
#       <td>569.000</td>
#       <td>569.000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>14.127</td>
#       <td>19.290</td>
#       <td>91.969</td>
#       <td>654.889</td>
#       <td>0.096</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>3.524</td>
#       <td>4.301</td>
#       <td>24.299</td>
#       <td>351.914</td>
#       <td>0.014</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>6.981</td>
#       <td>9.710</td>
#       <td>43.790</td>
#       <td>143.500</td>
#       <td>0.053</td>
#     </tr>
#     <tr>
#       <th>25%</th>
# ...

# %% [markdown]
# ## Tujuan Pembelajaran
# - Memahami algoritma K-Nearest Neighbors
# - Menentukan nilai K optimal
# - Mengevaluasi performa klasifikasi

# %% [markdown]
# ## 📊 Grafik 1 – Nilai K vs Akurasi
#
# Mencari nilai K terbaik untuk klasifikasi kanker payudara.

# %%
ks = range(1,16)
accs = [accuracy_score(y_te, KNeighborsClassifier(n_neighbors=k).fit(X_tr,y_tr).predict(X_te)) for k in ks]
plt.plot(ks, accs, marker="o")
plt.axvline(best_k, color="red", ls="--")
plt.title("KNN: Nilai K vs Akurasi")
plt.show()

# %% [markdown]
# **Insight:** Best K=9 dengan akurasi 0.9649. KNN berhasil mengklasifikasikan kanker payudara dengan akurasi tinggi.

# %% [markdown]
# ## 📈 Grafik 2 – Confusion Matrix
#
# Visualisasi confusion matrix model KNN terbaik.

# %%
cm = confusion_matrix(y_te, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title(f"Confusion Matrix KNN (K={best_k})")
plt.show()

# %% [markdown]
# **Insight:** Model berhasil mengklasifikasikan sebagian besar kasus dengan benar. True Positive dan True Negative mendominasi confusion matrix.

# %% [markdown]
# ## Kesimpulan
# Algoritma KNN dengan K=9 mencapai akurasi 0.9649 pada dataset Breast Cancer. Preprocessing dengan StandardScaler sangat penting untuk KNN.
