# %% [markdown]
# <a href="https://colab.research.google.com/github/RanzCoder119/MK_DataScience_2026/blob/main/Pertemuan5_RANU_RATMAJA_230401010104.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practice 5 - Decision Tree
#
# **Nama:** RANU RATMAJA
# **NIM:** 230401010104
# **Mata Kuliah: Data Science | Prodi Informatika**

# %% [markdown]
# ## Import Library & Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_wine
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# ## Statistik Deskriptif

# %%
df = pd.DataFrame(wine.data, columns=wine.feature_names)
df["class"] = wine.target
display(df.iloc[:,:5].describe())
# Out:
# <table class="dataframe table table-striped">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>alcohol</th>
#       <th>malic_acid</th>
#       <th>ash</th>
#       <th>alcalinity_of_ash</th>
#       <th>magnesium</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>178.000</td>
#       <td>178.000</td>
#       <td>178.000</td>
#       <td>178.000</td>
#       <td>178.000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>13.001</td>
#       <td>2.336</td>
#       <td>2.367</td>
#       <td>19.495</td>
#       <td>99.742</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>0.812</td>
#       <td>1.117</td>
#       <td>0.274</td>
#       <td>3.340</td>
#       <td>14.282</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>11.030</td>
#       <td>0.740</td>
#       <td>1.360</td>
#       <td>10.600</td>
#       <td>70.000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
# ...

# %% [markdown]
# ## Tujuan Pembelajaran
# - Memahami algoritma Decision Tree
# - Menemukan kedalaman pohon optimal
# - Menganalisis feature importance

# %% [markdown]
# ## 🌳 Grafik 1 – Max Depth vs Akurasi
#
# Menentukan kedalaman pohon keputusan yang optimal.

# %%
depths = range(1,11)
accs = [accuracy_score(y_te, DecisionTreeClassifier(max_depth=d, random_state=42).fit(X_tr,y_tr).predict(X_te)) for d in depths]
plt.plot(depths, accs, marker="s", color="#c44e52")
plt.axvline(best_d, color="blue", ls="--", label=f"Best Depth={best_d}")
plt.title("Decision Tree: Max Depth vs Akurasi")
plt.legend()
plt.show()

# %% [markdown]
# **Insight:** Best depth=3 dengan akurasi 0.9444. Decision Tree mampu mengklasifikasikan wine dengan sangat baik.

# %% [markdown]
# ## 📊 Grafik 2 – Feature Importance
#
# Menampilkan fitur-fitur paling penting dalam klasifikasi wine.

# %%
feat_imp = pd.Series(dt.feature_importances_, index=wine.feature_names).sort_values(ascending=False)[:8]
feat_imp.plot(kind="barh", color="#4c72b0")
plt.title("Feature Importance - Decision Tree")
plt.show()

# %% [markdown]
# **Insight:** Fitur-fitur kimia seperti flavanoids dan proline memiliki kontribusi terbesar dalam klasifikasi jenis wine.

# %% [markdown]
# ## Kesimpulan
# Decision Tree dengan max_depth=3 berhasil mengklasifikasikan wine dengan akurasi 0.9444. Feature importance membantu memahami variabel kunci.
