# %% [markdown]
# <a href="https://colab.research.google.com/github/RanzCoder119/MK_DataScience_2026/blob/main/Pertemuan3_RANU_RATMAJA_230401010104.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Practice 3 - Visualisasi Data
#
# ## 🎓 Student Information
#
# - **Name:** Ranu Ratmaja
# - **NIM:** 230401010104
# - **University:** UNSIA - Universitas Siber Asia
# - **Class:** IF401 Data Science

# %% [markdown]
# ## Import Library & Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## Statistik Deskriptif

# %%
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)
df["target"] = diabetes.target
display(df.describe())
# Out:
# <table class="dataframe table table-striped">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>bmi</th>
#       <th>bp</th>
#       <th>s1</th>
#       <th>s2</th>
#       <th>s3</th>
#       <th>s4</th>
#       <th>s5</th>
#       <th>s6</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#       <td>442.000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>-0.000</td>
#       <td>0.000</td>
#       <td>-0.000</td>
#       <td>-0.000</td>
#       <td>-0.000</td>
#       <td>0.000</td>
#       <td>-0.000</td>
#       <td>-0.000</td>
#       <td>0.000</td>
#       <td>0.000</td>
#       <td>152.133</td>
# ...

# %% [markdown]
# ## Tujuan Pembelajaran
# - Memahami konsep regresi linear
# - Melatih model prediksi pada data diabetes
# - Mengevaluasi model dengan MSE dan R2

# %% [markdown]
# ## 📈 Grafik 1 – Regresi Linear: BMI vs Diabetes Progression
#
# Visualisasi garis regresi terhadap data aktual.

# %%
fig, ax = plt.subplots(figsize=(9,5))
ax.scatter(X_te, y_te, alpha=0.5, color="#4c72b0", label="Data Aktual")
ax.plot(X_te, reg.predict(X_te), color="red", lw=2, label="Regresi Linear")
ax.set_title("Regresi Linear: BMI vs Diabetes Progression", fontsize=14, weight="bold")
ax.legend()
plt.show()

# %% [markdown]
# **Insight:** R² = 0.233, MSE = 4061.83. Model regresi menunjukkan hubungan positif antara BMI dan perkembangan diabetes.

# %% [markdown]
# ## 📉 Grafik 2 – Residual Plot
#
# Menampilkan sebaran residual untuk mengevaluasi asumsi linearitas.

# %%
fig, ax = plt.subplots(figsize=(9,5))
ax.scatter(y_pred, residuals, alpha=0.5, color="#55a868")
ax.axhline(0, color="red", lw=2, ls="--")
plt.show()

# %% [markdown]
# **Insight:** Residual tersebar merata di sekitar nol, mengindikasikan model regresi sudah cukup baik.

# %% [markdown]
# ---
#
# ## ✅ Kesimpulan
#
# **Pertemuan 3 — Visualisasi Data**
#
# Visualisasi data menjadi jembatan antara analisis statistik dan pemahaman bisnis.
#
# **Temuan Utama:**
# - Scatter plot dan heatmap efektif mengungkap pola korelasi antar variabel
# - Pasangan fitur petal_length–petal_width memiliki korelasi sangat tinggi (>0.96)
# - Pair plot memudahkan analisis multivariat dalam satu tampilan ringkas
#
# **Keterbatasan & Pertanyaan:**
# - Visualisasi statis terbatas untuk dataset berdimensi tinggi
# - Teknik visualisasi interaktif (Plotly, Bokeh) perlu dipelajari untuk presentasi lebih dinamis
